# %% [markdown]
# ## Data Cleaning and Feature Engineering
#
#
# After getting an understanding of our features and how they relate in part 1 (/titanic1.ipynb), we can start to clean up our data and also perform some feature engineering based off our results in preparation for model training. Like before, let's start by importing libraries and loading our data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
df = pd.read_csv("train.csv")
print(f"Original shape of the dataset: {df.shape}")
df.head()
# Out:
# Original shape of the dataset: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# Let's also do the missing value analysis from before.

# %%
missing_values = df.isna().sum()
print("Missing Values before cleaning:")
print(missing_values)

print("Total Missing Values:",df.isna().sum().sum())
# Out:
# Missing Values before cleaning:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Total Missing Values: 866

# %% [markdown]
# ## Handling Missing Values
#
# ### Cabin
# Cabin is missing 77% of the time, so we may want to delete the variable. However, we can check if the existence of cabin data somehow relates to survival

# %%
has_cabin_surv = df[df["Cabin"].isna()==False]["Survived"].mean()
no_cabin_surv = df[df["Cabin"].isna()==True]["Survived"].mean()

print(f"Survival rate for passengers with cabin information: {has_cabin_surv:.2%}")
print(f"Survival rate for passengers without cabin information: {no_cabin_surv:.2%}")
# Out:
# Survival rate for passengers with cabin information: 66.67%
# Survival rate for passengers without cabin information: 29.99%

# %% [markdown]
# The existance of cabin info seems correlated to survival, so we can drop Cabin data and introduce a new column that just defines whether there exists Cabin data or not

# %%
df["HasCabin"] = df["Cabin"].notna().astype(int)
df= df.drop(columns=["Cabin"])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  HasCabin
# 0      0         A/5 21171   7.2500        S         0
# 1      0          PC 17599  71.2833        C         1
# 2      0  STON/O2. 3101282   7.9250        S         0
# 3      0            113803  53.1000        S         1
# ...

# %% [markdown]
# For the missing age data, we can fill in missing data with the median age given gender and passenger class. Note that doing groupby([list]) produces a multi-index.

# %%
median_ages = df.groupby(["Sex","Pclass"])["Age"].median()
median_ages
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
# fill with group median
df["Age"] = df.groupby(["Sex","Pclass"])["Age"].transform(lambda x:x.fillna(x.median()))

# fill edge cases with overall  median
df["Age"] = df["Age"].fillna(df["Age"].median())

print("Missing Age Values after filling:",df["Age"].isna().sum())
# Out:
# Missing Age Values after filling: 0

# %% [markdown]
# Let's visualize what the age data looks like now with everything filled in.

# %%
fig ,ax = plt.subplots(figsize=(10,5))
ax.hist(df["Age"], bins=30, color="#3498db", edgecolor="white")
ax.set_title("Age Distribution After Imputation")
ax.set_xlabel("Age")
ax.set_ylabel("Count")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We have dealt with Cabin and Age, so all there is to deal with now is the Embarked missing. The first solution is simply to drop those two records that have no embarked data.

# %%
print(df.dropna().shape)
print(df[df["Embarked"].notna()].shape)
# Out:
# (889, 12)
# (889, 12)

# %% [markdown]
# Alternatively, we can fill the missing data with the mode.

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

# mode by gender example
# df.groupby("Sex")["Embarked"].transform(lambda x: x.fillna(x.mode()))

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Feature Engineering
#
# Now, let's use the information we gained from our feature analysis in part 1 to construct new features for use by our model. For example, we noted that title had a significant relationship with survival, so we can define that as a feature.

# %%
df["Title"]= df["Name"].apply(lambda x: x.split(",")[1].split(".")[0].strip())
df["Title"].value_counts()
# Out:
# Title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# Don               1
# Mme               1
# Ms                1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %% [markdown]
# We can use a Python map where every common title gets mapped with itself and every other title gets mapped to "Rare" using map.get(x, default_val)

# %%
# Group rare titles together
common_list={
    "Mr":"Mr",
    "Miss":"Miss",
    "Mrs":"Mrs",
    "Master":"Master"
}

df["Title"]=df["Title"].apply(lambda x : common_list.get(x,"Rare"))
print(df["Title"].value_counts())

df.groupby("Title")["Survived"].mean()
# Out:
# Title
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Rare       27
# Name: count, dtype: int64
# Title
# Master    0.575000
# Miss      0.697802
# Mr        0.156673
# Mrs       0.792000
# Rare      0.444444
# Name: Survived, dtype: float64

# %% [markdown]
# ## Family Size and isAlone

# %%
df["FamilySize"]= df["SibSp"] + df["Parch"]+1
df["IsAlone"]= df["FamilySize"].apply(lambda x : 1 if x== 1 else 0)

print(f"Solo Travelers: {df["IsAlone"].sum()}({df['IsAlone'].mean():.1%})")
print(f"\n Survival rate - alone: {df[df['IsAlone']==1]['Survived'].mean():.2%}")
print(f"\n Survival rate - not alone: {df[df['IsAlone']==0]['Survived'].mean():.2%}")
# Out:
# Solo Travelers: 537(60.3%)
#
#  Survival rate - alone: 30.35%
#
#  Survival rate - not alone: 50.56%

# %% [markdown]
# ## Age Groups
#
# We can bin ages into specific groups by using the **pd.cut()** method. The method segments continuous variables into categorical variables with the following parameters.
#
# * **`x`**: The input array to be binned (must be 1-dimensional).
# * **`bins`**: Defines the edges of our bins (e.g., `[0, 12, 18, 35, 60, 80]` creates intervals like `0-12`, `12-18`, etc.).
# * **`labels`**: The friendly names for each bin. The number of labels must be exactly **one less** than the number of bin edges (since $edges = bins + 1$).

# %%
df["AgeGroup"]= pd.cut(df["Age"] , bins =[0 , 12, 18 , 35 , 60 , 80 ],labels=["Child","Teen","Young Adult","Adult","Senior"])
print("Age Group Distribution:")
print(df["AgeGroup"].value_counts().sort_index())
print("Survival rate by Age Group:")
print(df.groupby("AgeGroup")["Survived"].mean())
# Out:
# Age Group Distribution:
# AgeGroup
# Child           69
# Teen            70
# Young Adult    514
# Adult          216
# Senior          22
# Name: count, dtype: int64
# Survival rate by Age Group:
# AgeGroup
# Child          0.579710
# Teen           0.428571
# Young Adult    0.357977
# Adult          0.384259
# Senior         0.227273
# Name: Survived, dtype: float64

# %% [markdown]
# An alternative to cutting by bins (discrete values) is to cut based on quartiles. For this, use the **pd.qcut()** method, and the most important difference is that instead of defining bins, you define
# *q* for the number of quartiles you want to cut with.

# %% [markdown]
# ## Fare Bins

# %%
df["FareBin"] = pd.qcut(df["Fare"], q=4, labels=["Low","Medium","High","Very High"])

print("Survival rate by Fare Bins:")
print(df.groupby("FareBin")["Survived"].mean())
# Out:
# Survival rate by Fare Bins:
# FareBin
# Low          0.197309
# Medium       0.303571
# High         0.454955
# Very High    0.581081
# Name: Survived, dtype: float64

# %% [markdown]
# ## Encoding Categorical Variables
#
# We need to either convert all string/object/categorical variables into numeric variables before using them in a model, or drop them. Use **df.dtypes** to get the datatypes of all the columns. An important technique to note is **one-hot encoding**. This converts a single object/categorical column with a few options into multiple columns where each is a boolean 0/1 based on if the row has that specific category (original column is deleted). So, if there are 3 possibilities of Embarked (C, Q, S), we convert Embarked into 3 boolean columns for C, Q, and S. The method is pd.get_dummies(), and the arguments are:
#
# * df: specific dataframe
# columns: column names to be one-hot encoded (if none passed, all object and string columns will be)
# * drop_first: wether to get k-1 dummies out of k categorical levels by removing the first level (saving one column)
# * dtype: resulting column datatype
# prefix: if you want to prepend a string to the new one-hot column names

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name                str
# Sex                 str
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket              str
# Fare            float64
# Embarked            str
# HasCabin          int64
# Title               str
# FamilySize        int64
# IsAlone           int64
# AgeGroup       category
# FareBin        category
# dtype: object

# %%
# Let's first map the Sex column to 0 and 1
df["Sex"] = df["Sex"].map({"male": 0, "female": 1}) # alternative: df["Sex"].apply(lambda x: 0 if x == "male" else 1)

df = pd.get_dummies(df, columns=["Embarked", "Title", "AgeGroup", "FareBin"], drop_first=True, dtype=int)

print(f"Shape after one-hot: {df.shape}")
df.head()
# Out:
# Shape after one-hot: (891, 26)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare  ...  Title_Mr  Title_Mrs  Title_Rare  \
# 0         A/5 21171   7.2500  ...         1          0           0
# 1          PC 17599  71.2833  ...         0          1           0
# ...

# %% [markdown]
# Now, let's drop unnnecessary columns

# %%
print(f"Original columns: {df.columns.tolist()}")
drop_cols = ["PassengerId", "Name", "Ticket"]

df = df.drop(columns=drop_cols)
print(f"Final Shape: {df.shape}")
print(f"Final columns: {df.columns.tolist()}")
# Out:
# Original columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'HasCabin', 'FamilySize', 'IsAlone', 'Embarked_Q', 'Embarked_S', 'Title_Miss', 'Title_Mr', 'Title_Mrs', 'Title_Rare', 'AgeGroup_Teen', 'AgeGroup_Young Adult', 'AgeGroup_Adult', 'AgeGroup_Senior', 'FareBin_Medium', 'FareBin_High', 'FareBin_Very High']
# Final Shape: (891, 23)
# Final columns: ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'HasCabin', 'FamilySize', 'IsAlone', 'Embarked_Q', 'Embarked_S', 'Title_Miss', 'Title_Mr', 'Title_Mrs', 'Title_Rare', 'AgeGroup_Teen', 'AgeGroup_Young Adult', 'AgeGroup_Adult', 'AgeGroup_Senior', 'FareBin_Medium', 'FareBin_High', 'FareBin_Very High']

# %% [markdown]
# Let's do a final check on our data cleaning.

# %%
print("Missing values: ")
print(df.isna().sum().sum())
print("\nColumn info:")
print(df.dtypes)
# Out:
# Missing values:
# 0
#
# Column info:
# Survived                  int64
# Pclass                    int64
# Sex                       int64
# Age                     float64
# SibSp                     int64
# Parch                     int64
# Fare                    float64
# HasCabin                  int64
# FamilySize                int64
# IsAlone                   int64
# Embarked_Q                int64
# Embarked_S                int64
# Title_Miss                int64
# Title_Mr                  int64
# Title_Mrs                 int64
# Title_Rare                int64
# AgeGroup_Teen             int64
# AgeGroup_Young Adult      int64
# AgeGroup_Adult            int64
# AgeGroup_Senior           int64
# FareBin_Medium            int64
# FareBin_High              int64
# FareBin_Very High         int64
# dtype: object

# %% [markdown]
# ## Save Clean Data
# Finally, let's save this cleaned data in a new CSV file so we can load this when we start model training.

# %%
df.to_csv("titanic_cleaned.csv", index=False)
print("Cleaned dataset saved to titanic_cleaned.csv")
print(f"Final shape: {df.shape}")
df.head()
# Out:
# Cleaned dataset saved to titanic_cleaned.csv
# Final shape: (891, 23)
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  HasCabin  FamilySize  \
# 0         0       3    0  22.0      1      0   7.2500         0           2
# 1         1       1    1  38.0      1      0  71.2833         1           2
# 2         1       3    1  26.0      0      0   7.9250         0           1
# 3         1       1    1  35.0      1      0  53.1000         1           2
# 4         0       3    0  35.0      0      0   8.0500         0           1
#
#    IsAlone  ...  Title_Mr  Title_Mrs  Title_Rare  AgeGroup_Teen  \
# 0        0  ...         1          0           0              0
# 1        0  ...         0          1           0              0
# 2        1  ...         0          0           0              0
# 3        0  ...         0          1           0              0
# 4        1  ...         1          0           0              0
#
# ...

# %% [markdown]
# ## Summary
#
# Here is a quick-reference summary of all the data cleaning and feature engineering steps we performed today to prepare our dataset for machine learning:
#
# | Feature / Step | Action Taken | Rationale |
# | :--- | :--- | :--- |
# | **Cabin** | Created `HasCabin` flag ($0$ or $1$), then dropped the raw column. | Over 77% of cabin data was missing, but having a recorded cabin strongly correlated with survival. |
# | **Age** | Imputed missing values using the **median** age of each passenger's specific `Pclass` and `Sex` group. | Avoids applying a generic average age to everyone, keeping the distribution realistic. |
# | **Embarked** | Filled the 2 missing values with the **mode** (`'S'`). | S was the most common embarkation port. |
# | **Title** | Extracted titles from names and grouped rare ones (e.g., `Dr`, `Rev`) into a `'Rare'` category. | Titles like `Mr` and `Mrs` carry strong social and survival indicators. |
# | **FamilySize** | Created a new column: `SibSp` + `Parch` + $1$. | Helps capture how family dynamics affected survival. |
# | **IsAlone** | Created a binary flag ($1$ if `FamilySize` == 1, else $0$). | Solo travelers had a significantly lower survival rate than those with family. |
# | **AgeGroup** | Binned `Age` into 5 categories using `pd.cut()`. | Smooths out noise in continuous age values by grouping passengers into life stages. |
# | **FareBin** | Binned `Fare` into 4 equal-sized quartiles using `pd.qcut()`. | Groups passenger ticket prices into Low, Medium, High, and Very High buckets. |
# | **Encoding** | Mapped `Sex` to $0$/$1$ and applied **One-Hot Encoding** to categorical columns. | Machine learning models require completely numerical inputs. |
# | **Dropped** | Removed `PassengerId`, `Name`, and `Ticket`. | These unique identifiers do not contain patterns that help a model generalize to new data. |
